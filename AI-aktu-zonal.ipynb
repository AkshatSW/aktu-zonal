# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/ai-powered-loan-approval-prediction-model/sample_submission.csv
# /kaggle/input/ai-powered-loan-approval-prediction-model/train.csv
# /kaggle/input/ai-powered-loan-approval-prediction-model/test.csv

# %% [markdown]
# age
# income
# rent/ownership
# emp length
# loan amont

# %%
data = pd.read_csv('/kaggle/input/ai-powered-loan-approval-prediction-model/train.csv')

# %%
data
# Out:
#           id  person_age  person_income person_home_ownership  \
# 0          0          37          35000                  RENT
# 1          1          22          56000                   OWN
# 2          2          29          28800                   OWN
# 3          3          30          70000                  RENT
# 4          4          22          60000                  RENT
# ...      ...         ...            ...                   ...
# 58640  58640          34         120000              MORTGAGE
# 58641  58641          28          28800                  RENT
# 58642  58642          23          44000                  RENT
# 58643  58643          22          30000                  RENT
# 58644  58644          31          75000              MORTGAGE
#
#        person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                    0.0   EDUCATION          B       6000          11.49
# ...

# %%
pd.isnull(data)
# Out:
#           id  person_age  person_income  person_home_ownership  \
# 0      False       False          False                  False
# 1      False       False          False                  False
# 2      False       False          False                  False
# 3      False       False          False                  False
# 4      False       False          False                  False
# ...      ...         ...            ...                    ...
# 58640  False       False          False                  False
# 58641  False       False          False                  False
# 58642  False       False          False                  False
# 58643  False       False          False                  False
# 58644  False       False          False                  False
#
#        person_emp_length  loan_intent  loan_grade  loan_amnt  loan_int_rate  \
# 0                  False        False       False      False          False
# ...

# %%
data = data.drop_duplicates

# %%
data
# Out:
# <bound method DataFrame.drop_duplicates of           id  person_age  person_income person_home_ownership  \
# 0          0          37          35000                  RENT
# 1          1          22          56000                   OWN
# 2          2          29          28800                   OWN
# 3          3          30          70000                  RENT
# 4          4          22          60000                  RENT
# ...      ...         ...            ...                   ...
# 58640  58640          34         120000              MORTGAGE
# 58641  58641          28          28800                  RENT
# 58642  58642          23          44000                  RENT
# 58643  58643          22          30000                  RENT
# 58644  58644          31          75000              MORTGAGE
#
#        person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                    0.0   EDUCATION          B       6000          11.49
# ...

# %%
from sklearn.preprocessing import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 from sklearn.preprocessing import LinearRegression
#
# ImportError: cannot import name 'LinearRegression' from 'sklearn.preprocessing' (/opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/__init__.py)

# %%
from sklearn.preprocessing import LinearRegression
from sklearn.preprocessing import train_test_split

# %%
linearR = LinearRegression(data)
data.linearR()

# %%
data1 = pd.read_csv('/kaggle/input/ai-powered-loan-approval-prediction-model/train.csv')

# %%
data1
# Out:
#           id  person_age  person_income person_home_ownership  \
# 0          0          37          35000                  RENT
# 1          1          22          56000                   OWN
# 2          2          29          28800                   OWN
# 3          3          30          70000                  RENT
# 4          4          22          60000                  RENT
# ...      ...         ...            ...                   ...
# 58640  58640          34         120000              MORTGAGE
# 58641  58641          28          28800                  RENT
# 58642  58642          23          44000                  RENT
# 58643  58643          22          30000                  RENT
# 58644  58644          31          75000              MORTGAGE
#
#        person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                    0.0   EDUCATION          B       6000          11.49
# ...

# %%
def train():
    if person_income>=50000 && loan_intent==MEDICAL || EDUCATION:
        train_test_split(data)

# %%
def train():
    if person_income>=50000 && loan_intent==MEDICAL || EDUCATION:
        data.lr()
